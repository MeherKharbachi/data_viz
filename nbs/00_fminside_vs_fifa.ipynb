# %% [markdown]
# # Fminside vs Fifa
#
# > Visualize fminside and fifa stats distributions

# %%
#| default_exp fminside_vs_fifa

# %% [markdown]
# # Import packages

# %%
#| export
import pandas as pd
from pivottablejs import pivot_ui

# %% [markdown]
# # Load data

# %%
#| export
# fminside data
df_fm = pd.read_csv("pl_fm_stats.csv")
df_fm["data"] = "Fminside"

# %%
df_fm.head()
# Out:
#    playerId  fminsideId         known_name           long_name  year_birth  \
# 0    221820    14167329  Lisandro Martínez  Lisandro  Martínez        1998
# 1    232937    28115834   Brandon Williams   Brandon  Williams        2000
# 2     67089    63002306    Martin Dúbravka    Martin  Dúbravka        1989
# 3     51940    67030171       David de Gea       David  de Gea        1990
# 4    176297    28100266    Marcus Rashford    Marcus  Rashford        1997
#
#    month_birth  day_birth  age  height_cm  weight_kg  ...  Strength Stamina  \
# 0            1         18   25      175.0       77.0  ...        65      75
# 1            9          3   22      171.0       63.0  ...        50      70
# 2            1         15   34      190.0       83.0  ...        60      50
# 3           11          7   32      192.0       76.0  ...        65      60
# 4           10         31   25      180.0       70.0  ...        65      70
#
#    GK Diving/One to One GK Handling  GK Kicking  GK Positioning  GK Reflexes  \
# 0                     0           0           0              70            0
# 1                     0           0           0              50            0
# 2                    80          70          70              75           85
# 3                    70          80          70              75           95
# 4                     0           0           0              20            0
#
#    Height                 bucket      data
# 0     178             Full_backs  Fminside
# 1     182             Full_backs  Fminside
# 2     190             Goalkeeper  Fminside
# 3     192             Goalkeeper  Fminside
# 4     185  Attacking_midfielders  Fminside
#
# [5 rows x 38 columns]

# %%
#| export
# fifa data
df_fifa = pd.read_csv("pl_fifa_stats.csv")
df_fifa["data"] = "Fifa"

# %%
#| hide
df_fifa.head()
# Out:
#    playerId  fminsideId         known_name           long_name  year_birth  \
# 0    221820    14167329  Lisandro Martínez  Lisandro  Martínez        1998
# 1    221820    14167329  Lisandro Martínez  Lisandro  Martínez        1998
# 2    232937    28115834   Brandon Williams   Brandon  Williams        2000
# 3     67089    63002306    Martin Dúbravka    Martin  Dúbravka        1989
# 4     51940    67030171       David de Gea       David  de Gea        1990
#
#    month_birth  day_birth  age  height_cm  weight_kg  ...  Strength Stamina  \
# 0            1         18   25      175.0       77.0  ...        81      85
# 1            1         18   25      175.0       77.0  ...        81      85
# 2            9          3   22      171.0       63.0  ...        59      74
# 3            1         15   34      190.0       83.0  ...        60      38
# 4           11          7   32      192.0       76.0  ...        55      43
#
#    GK Diving/One to One GK Handling  GK Kicking  GK Positioning  GK Reflexes  \
# 0                     6          14          13              14            8
# 1                     6          14          13              14            8
# 2                    10          13          11               7            7
# 3                    78          76          79              77           81
# 4                    88          80          76              84           89
#
#    Height             bucket  data
# 0     178  Central_defenders  Fifa
# 1     178  Central_defenders  Fifa
# 2     182         Full_backs  Fifa
# 3     190         Goalkeeper  Fifa
# 4     192         Goalkeeper  Fifa
#
# [5 rows x 38 columns]

# %%
#| export
df_stats = pd.concat([df_fm, df_fifa])

# %% [markdown]
# # Data Exploration

# %%
#| export
pivot_ui(df_stats)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#| hide
import nbdev; nbdev.nbdev_export()
